# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Dataset

# %%
gapminder_df = pd.read_csv('gapminder.csv')

# %%
gapminder_df
# Out:
#                 country   incomeperperson alcconsumption armedforcesrate  \
# 0           Afghanistan                              .03        .5696534
# 1               Albania  1914.99655094922           7.29       1.0247361
# 2               Algeria  2231.99333515006            .69        2.306817
# 3               Andorra  21943.3398976022          10.17
# 4                Angola  1381.00426770244           5.57       1.4613288
# ..                  ...               ...            ...             ...
# 208             Vietnam  722.807558834445           3.91       1.0853671
# 209  West Bank and Gaza                                        5.9360854
# 210         Yemen, Rep.    610.3573673206             .2       2.3162346
# 211              Zambia  432.226336974583           3.56        .3413352
# 212            Zimbabwe  320.771889948584           4.96       1.0327854
#
#     breastcancerper100th      co2emissions  femaleemployrate hivrate  \
# ...

# %%
#number of rows and columns in dataset
print(len(gapminder_df))#number of observations(rows)
print(len(gapminder_df.columns))#number of variables(columns)
# Out:
# 213
# 16

# %%
gapminder_df.dtypes #datatypes of the variables(columns)
# Out:
# country                 object
# incomeperperson         object
# alcconsumption          object
# armedforcesrate         object
# breastcancerper100th    object
# co2emissions            object
# femaleemployrate        object
# hivrate                 object
# internetuserate         object
# lifeexpectancy          object
# oilperperson            object
# polityscore             object
# relectricperperson      object
# suicideper100th         object
# employrate              object
# urbanrate               object
# dtype: object

# %%
gapminder_df['incomeperperson'] #frequency distribution of variable incomeperperson
# Out:
# 0
# 1      1914.99655094922
# 2      2231.99333515006
# 3      21943.3398976022
# 4      1381.00426770244
#              ...
# 208    722.807558834445
# 209
# 210      610.3573673206
# 211    432.226336974583
# 212    320.771889948584
# Name: incomeperperson, Length: 213, dtype: object

# %%
gapminder_df['incomeperperson'][0] #the value of the variable incomeperperson in the first row is an empty string
# Out:
# ' '

# %% [markdown]
# ### Counting number of empty rows in incomeperperson, alcconsumption & suicideper100th

# %%
new_df_ipp = gapminder_df[(gapminder_df["incomeperperson"] == ' ')]
print(len(new_df_ipp))
# Out:
# 23

# %%
new_df_ac = gapminder_df[(gapminder_df["alcconsumption"] == ' ')]
print(len(new_df_ac))
# Out:
# 26

# %%
new_df_suicide = gapminder_df[(gapminder_df["suicideper100th"] == ' ')]
print(len(new_df_suicide))
# Out:
# 22

# %% [markdown]
# ### Drop all rows where incomeperperson = ' '

# %%
gapminder_df.drop(gapminder_df[gapminder_df['incomeperperson'] == ' '].index, inplace = True)

# %%
gapminder_df
# Out:
#                  country   incomeperperson alcconsumption armedforcesrate  \
# 1                Albania  1914.99655094922           7.29       1.0247361
# 2                Algeria  2231.99333515006            .69        2.306817
# 3                Andorra  21943.3398976022          10.17
# 4                 Angola  1381.00426770244           5.57       1.4613288
# 5    Antigua and Barbuda  11894.4640745081           8.17
# ..                   ...               ...            ...             ...
# 207            Venezuela  5528.36311387522            7.6        .9040245
# 208              Vietnam  722.807558834445           3.91       1.0853671
# 210          Yemen, Rep.    610.3573673206             .2       2.3162346
# 211               Zambia  432.226336974583           3.56        .3413352
# 212             Zimbabwe  320.771889948584           4.96       1.0327854
#
#     breastcancerper100th      co2emissions  femaleemployrate hivrate  \
# ...

# %% [markdown]
# ### Drop all rows where alcconsumption = ' '

# %%
gapminder_df.drop(gapminder_df[gapminder_df['alcconsumption'] == ' '].index, inplace = True)

# %%
gapminder_df
# Out:
#                  country   incomeperperson alcconsumption armedforcesrate  \
# 1                Albania  1914.99655094922           7.29       1.0247361
# 2                Algeria  2231.99333515006            .69        2.306817
# 3                Andorra  21943.3398976022          10.17
# 4                 Angola  1381.00426770244           5.57       1.4613288
# 5    Antigua and Barbuda  11894.4640745081           8.17
# ..                   ...               ...            ...             ...
# 207            Venezuela  5528.36311387522            7.6        .9040245
# 208              Vietnam  722.807558834445           3.91       1.0853671
# 210          Yemen, Rep.    610.3573673206             .2       2.3162346
# 211               Zambia  432.226336974583           3.56        .3413352
# 212             Zimbabwe  320.771889948584           4.96       1.0327854
#
#     breastcancerper100th      co2emissions  femaleemployrate hivrate  \
# ...

# %% [markdown]
# ### Drop all rows where suicideper100th = ' '

# %%
gapminder_df.drop(gapminder_df[gapminder_df['suicideper100th'] == ' '].index, inplace = True)

# %%
gapminder_df
# Out:
#                  country   incomeperperson alcconsumption armedforcesrate  \
# 1                Albania  1914.99655094922           7.29       1.0247361
# 2                Algeria  2231.99333515006            .69        2.306817
# 3                Andorra  21943.3398976022          10.17
# 4                 Angola  1381.00426770244           5.57       1.4613288
# 5    Antigua and Barbuda  11894.4640745081           8.17
# ..                   ...               ...            ...             ...
# 207            Venezuela  5528.36311387522            7.6        .9040245
# 208              Vietnam  722.807558834445           3.91       1.0853671
# 210          Yemen, Rep.    610.3573673206             .2       2.3162346
# 211               Zambia  432.226336974583           3.56        .3413352
# 212             Zimbabwe  320.771889948584           4.96       1.0327854
#
#     breastcancerper100th      co2emissions  femaleemployrate hivrate  \
# ...

# %% [markdown]
# ### Change the datatype of the 3 columns into float

# %%
gapminder_df['incomeperperson'] = gapminder_df['incomeperperson'].astype(float)

# %%
gapminder_df['alcconsumption'] = gapminder_df['alcconsumption'].astype(float)

# %%
gapminder_df['suicideper100th'] = gapminder_df['suicideper100th'].astype(float)

# %%
gapminder_df.dtypes
# Out:
# country                  object
# incomeperperson         float64
# alcconsumption          float64
# armedforcesrate          object
# breastcancerper100th     object
# co2emissions             object
# femaleemployrate         object
# hivrate                  object
# internetuserate          object
# lifeexpectancy           object
# oilperperson             object
# polityscore              object
# relectricperperson       object
# suicideper100th         float64
# employrate               object
# urbanrate                object
# dtype: object

# %% [markdown]
# ### Plotting univariate graphs for each variable

# %%
# Histogram
plt.rcParams["figure.figsize"] = (9, 7)
plt.hist(gapminder_df['incomeperperson'])
plt.xlabel("Income per person", fontsize=15)
plt.title("Income per person - Worldwide", fontsize=20, color='green')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (9, 7)
plt.hist(gapminder_df['suicideper100th'])
plt.xlabel("Suicide per 100TH", fontsize=15)
plt.title("Suicide per Hunderd Thousand - Worldwide", fontsize=20, color='green')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (9, 7)
plt.hist(gapminder_df['alcconsumption'])
plt.xlabel("Alcohol Consumption", fontsize=15)
plt.title("Alcohol Consumption - Worldwide", fontsize=20, color='green')
plt.show()

# %% [markdown]
# ### Calculating center and spread for each variable

# %%
descr1 = gapminder_df["incomeperperson"].describe()
print(descr1)
# Out:
# count      177.000000
# mean      7088.394031
# std      10166.195989
# min        103.775857
# 25%        713.639303
# 50%       2425.471293
# 75%       8445.526689
# max      52301.587179
# Name: incomeperperson, dtype: float64

# %%
descr2 = gapminder_df["suicideper100th"].describe()
print(descr2)
# Out:
# count    177.000000
# mean       9.627546
# std        6.187681
# min        0.201449
# 25%        5.213720
# 50%        8.283071
# 75%       12.367980
# max       35.752872
# Name: suicideper100th, dtype: float64

# %%
descr2 = gapminder_df["alcconsumption"].describe()
print(descr2)
# Out:
# count    177.000000
# mean       6.842994
# std        4.910343
# min        0.050000
# 25%        2.760000
# 50%        6.120000
# 75%        9.990000
# max       23.010000
# Name: alcconsumption, dtype: float64

# %% [markdown]
# ### Correlation between incomeperperson, alcconsumption, suicideper100th

# %%
corr = gapminder_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_61aa9292_c400_11ea_ab63_6003089f6e06row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_61aa9292_c400_11ea_ab63_6003089f6e06row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_61aa9292_c400_11ea_ab63_6003089f6e06row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_61aa9292_c400_11ea_ab63_6003089f6e06row1_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_61aa9292_c400_11ea_ab63_6003089f6e06row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_61aa9292_c400_11ea_ab63_6003089f6e06row1_col2 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_61aa9292_c400_11ea_ab63_6003089f6e06row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# #### Correlation between incomeperperson and alcconsumption is 0.292965 which is a moderate-to-low +ve correlation

# %% [markdown]
# #### Correlation between incomeperperson and suicideper100th is 0.005731 which signifies no correlation

# %% [markdown]
# ### Plotting bivariate Scatter plot for quantitative values.

# %%
plt.scatter(gapminder_df['incomeperperson'], gapminder_df['suicideper100th'])
plt.rcParams["figure.figsize"] = (9, 7)
plt.title("Income per Person Vs Suicide rate", fontsize=20, color='green')
plt.xlabel("Income per Person", fontsize=15)
plt.ylabel("Suicide per 100th", fontsize=15)

m, b = np.polyfit(gapminder_df['incomeperperson'],gapminder_df['suicideper100th'], 1)
plt.plot(gapminder_df['incomeperperson'], m*gapminder_df['incomeperperson'] + b)

plt.show()

# %%
plt.scatter(gapminder_df['incomeperperson'], gapminder_df['alcconsumption'])
plt.rcParams["figure.figsize"] = (9, 7)
plt.title("Income per Person Vs Alcohol Consumption", fontsize=20, color='green')
plt.xlabel("Income per Person", fontsize=15)
plt.ylabel("Alcohol Consumption", fontsize=15)

m, b = np.polyfit(gapminder_df['incomeperperson'],gapminder_df['alcconsumption'], 1)
plt.plot(gapminder_df['incomeperperson'], m*gapminder_df['incomeperperson'] + b)

plt.show()
